# %% [markdown]
# # Proyecto: Comparación de Algoritmos de Ordenamiento Paralelo en CPU y GPU
#
# ---
#
# ## Sprint 0: Avance Inicial
#
# **Objetivo del Sprint 0:**
# Desarrollar la versión secuencial de los algoritmos de ordenamiento seleccionados (MergeSort y QuickSort), preparar el entorno de desarrollo para futuras etapas de paralelización, y organizar la estructura general del proyecto.

# %% [markdown]
# ## 1. Algoritmos Secuenciales Implementados
#
# Se desarrollaron los algoritmos de ordenamiento **MergeSort** y **QuickSort** en C++, con énfasis en la claridad modular del código para facilitar su posterior paralelización.

# %%
// QuickSort Secuencial en C++
void quickSort(std::vector<int>& arr, int left, int right) {
    int i = left, j = right;
    int pivot = arr[(left + right) / 2];

    while (i <= j) {
        while (arr[i] < pivot) i++;
        while (arr[j] > pivot) j--;
        if (i <= j) {
            std::swap(arr[i], arr[j]);
            i++;
            j--;
        }
    }

    if (left < j) quickSort(arr, left, j);
    if (i < right) quickSort(arr, i, right);
}

# %%
// MergeSort Secuencial en C++
void merge(std::vector<int>& arr, int l, int m, int r) {
    int n1 = m - l + 1;
    int n2 = r - m;
    std::vector<int> L(n1), R(n2);
    for (int i = 0; i < n1; i++) L[i] = arr[l + i];
    for (int j = 0; j < n2; j++) R[j] = arr[m + 1 + j];

    int i = 0, j = 0, k = l;
    while (i < n1 && j < n2) {
        if (L[i] <= R[j]) arr[k++] = L[i++];
        else arr[k++] = R[j++];
    }
    while (i < n1) arr[k++] = L[i++];
    while (j < n2) arr[k++] = R[j++];
}

void mergeSort(std::vector<int>& arr, int l, int r) {
    if (l < r) {
        int m = l + (r - l) / 2;
        mergeSort(arr, l, m);
        mergeSort(arr, m + 1, r);
        merge(arr, l, m, r);
    }
}

# %% [markdown]
# ## 2. Validación de los Algoritmos
#
# Se realizaron pruebas unitarias con datos generados aleatoriamente para validar el correcto funcionamiento:
# - Tamaños probados: 10³, 10⁵, 10⁶
# - Comparación con `std::sort` para validar precisión de ordenamiento.

# %%
// Generación de datos aleatorios para prueba
std::vector<int> generateRandomArray(int size) {
    std::vector<int> arr(size);
    std::generate(arr.begin(), arr.end(), [](){ return rand() % 10000; });
    return arr;
}

# %% [markdown]
# ## 3. Entorno de Desarrollo Configurado
#
# - Lenguaje de programación: **C++**
# - Compilador: **g++ 11.2.0** con flags de optimización `-O2`
# - Plataforma de prueba:
#   - CPU: Intel Core i7-10700 (8 núcleos / 16 hilos)
#   - Sistema operativo: Ubuntu 22.04
#   - CUDA Toolkit 12.3 instalado

# %% [markdown]
# ## 4. Modularización y Preparación para Paralelización
#
# - Separación clara entre funciones recursivas y manejo de datos
# - Uso de `std::vector` para mejor compatibilidad
# - Diseño de interfaz de pruebas para comparar implementaciones.

# %% [markdown]
# ## 5. Conclusión del Sprint 0
#
# El sprint inicial permitió construir una base sólida:
# - Implementaciones secuenciales completas
# - Validaciones exitosas
# - Entorno de pruebas listo
#
# El proyecto está preparado para comenzar la paralelización en CPU mediante **OpenMP** en el siguiente sprint.
